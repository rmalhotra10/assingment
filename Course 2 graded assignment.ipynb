# %% [markdown]
# # My Jupyter Notebook in IBM Watson Studio

# %% [markdown]
# **Richa Malhotra**

# %% [markdown]
# *I am interested in data science because I want to learn how data can be used to make advancements in the medical field.*

# %% [markdown]
# ### The next cell is going to show a simple arithmetic function

# %%
(2 + 4)/3
# Out:
# 2.0

# %% [markdown]
# | header | header |
# | ------ | ------ |
# | 1. one | 1. one |
# | 2. two | 2. ~~two~~ |
